# %%
import logging
import matplotlib.pyplot as plt
import sys
import os

# %%
sys.path.append(os.path.abspath('../scripts'))
# Setup logger

# %%
train_path = '../data/train.csv'
store_path = '../data/store.csv'

# %%
from eda_analysis_function import load_and_merge_data, clean_merged_data,setup_logger
from eda_analysis_function import (analyze_promo_sales, analyze_store_sales,analyze_competition_effect,analyze_sales_over_time,
analyze_sales_over_time, analyze_sales_by_day_of_week, analyze_sales_vs_promo_by_day, analyze_sales_by_assortment,analyze_sales_vs_competition_open)

# %%
setup_logger()

# %%
# Load and merge datasets
merged_df = load_and_merge_data(train_path, store_path)
if merged_df is not None:
    logging.info("Data loaded successfully in notebook.")
else:
    logging.error("Data loading failed.")
# Out:
# c:\Users\ftesfaye\Desktop\KIFIYA\KIFIYA_PROJECT_WEEK_4\kifiya_week_4\scripts\eda_analysis_function.py:12: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv(train_path)

# %%
# Clean Data
cleaned_df = clean_merged_data(merged_df)

if cleaned_df is not None:
    logging.info("Data cleaned successfully in notebook.")
else:
    logging.error("Data cleaning failed.")
# Out:
# c:\Users\ftesfaye\Desktop\KIFIYA\KIFIYA_PROJECT_WEEK_4\kifiya_week_4\scripts\eda_analysis_function.py:31: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
analyze_promo_sales(cleaned_df)

# %%
analyze_store_sales(cleaned_df)

# %%
analyze_competition_effect(cleaned_df)

# %%
analyze_sales_over_time(cleaned_df)
# Out:
# c:\Users\ftesfaye\Desktop\KIFIYA\KIFIYA_PROJECT_WEEK_4\kifiya_week_4\scripts\eda_analysis_function.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
# c:\Users\ftesfaye\Desktop\KIFIYA\KIFIYA_PROJECT_WEEK_4\kifiya_week_4\scripts\eda_analysis_function.py:92: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df['Sales'].resample('M').sum().plot()

# %%
analyze_sales_by_day_of_week(cleaned_df)

# %%
analyze_sales_vs_promo_by_day(cleaned_df)

# %%
analyze_sales_by_assortment(cleaned_df)

# %%
analyze_sales_vs_competition_open(cleaned_df)
# Out:
# c:\Users\ftesfaye\Desktop\KIFIYA\KIFIYA_PROJECT_WEEK_4\kifiya_week_4\scripts\eda_analysis_function.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CompetitionOpen'] = pd.to_datetime(df['CompetitionOpenSinceYear'].astype('int').astype(str) + '-' + df['CompetitionOpenSinceMonth'].astype('int').astype(str), errors='coerce')
